# %% [markdown]
# # Legadia — vídeo publicitario disruptivo
#
# Pipeline gratuito con CogVideoX-5B INT8, Edge TTS, LatentSync 1.5 y FFmpeg.
#
# Antes de ejecutar: **Entorno de ejecución → Cambiar tipo de entorno de ejecución → T4 GPU**.

# %%
# !rm -rf /content/skyreels
# !git clone -q https://github.com/uptobe8/skyreels.git /content/skyreels
# !bash /content/skyreels/colab/install.sh

# %%
# !python /content/skyreels/colab/generate.py

# %%
# !python /content/skyreels/colab/audio.py

# %%
# !bash /content/skyreels/colab/lipsync.sh

# %%
# !python /content/skyreels/colab/master.py
from IPython.display import Video, display
from google.colab import files
final = '/content/legadia/output/LEGADIA_FINAL_1080P.mp4'
display(Video(final, embed=True, width=960))
files.download(final)
